# %% [markdown]
# # 双向循环神经网络

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 双向的循环神经网络，前向的隐层和后向的隐层，初始状态都可以设置成0，权重之间没有关系（也就是自己有自己的权重）

# %% [markdown]
# #### 双向循环神经网络的错误应用：不要用来预测，如下面预测下一个词

# %%
# 下面两行是防止内核挂掉加的
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import torch
from torch import nn
from d2l import torch as d2l

batch_size, num_steps, device = 32, 35, d2l.try_gpu()
train_iter, vocab = d2l.load_data_time_machine(batch_size, num_steps)
vocab_size, num_hiddens, num_layers = len(vocab), 256, 2
num_inputs = vocab_size
lstm_layer = nn.LSTM(num_inputs, num_hiddens, num_layers, bidirectional=True) # pytorch框架只需要使得bidirectional=True即可双向
model = d2l.RNNModel(lstm_layer, len(vocab))
model = model.to(device)
num_epochs, lr = 500, 1
d2l.train_ch8(model, train_iter, vocab, lr, num_epochs, device)
# Out:
# perplexity 1.1, 104434.2 tokens/sec on cuda:0
# time travellerererererererererererererererererererererererererer
# travellerererererererererererererererererererererererererer

# %% [markdown]
# ![image.png](attachment:image.png)
