# %% [markdown]
# 梯度消失

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %matplotlib inline
import torch
from d2l import torch as d2l

x = torch.arange(-8.0, 8.0, 0.1, requires_grad=True)
y = torch.sigmoid(x)
y.backward(torch.ones_like(x))

d2l.plot(x.detach().numpy(), [y.detach().numpy(), x.grad.numpy()],
         legend=['sigmoid', 'gradient'], figsize=(4.5, 2.5))

# %% [markdown]
# 梯度爆炸

# %%
M = torch.normal(0, 1, size=(4, 4))
print('一个矩阵 \n', M)
for i in range(100):
    M = torch.mm(M, torch.normal(0, 1, size=(4, 4)))

print('乘以100个矩阵后\n', M)
# Out:
# 一个矩阵
#  tensor([[-0.5319, -0.5794,  1.7620, -0.8325],
#         [ 0.0194, -0.0038,  0.5618, -0.5107],
#         [-0.9396, -2.4131,  0.1961, -2.0284],
#         [-2.8172, -0.2580, -0.4645, -1.5237]])
# 乘以100个矩阵后
#  tensor([[-4.1824e+22,  2.7364e+24,  3.9618e+23,  7.7380e+22],
#         [-6.0920e+21,  3.9858e+23,  5.7708e+22,  1.1271e+22],
#         [-1.0477e+23,  6.8548e+24,  9.9247e+23,  1.9385e+23],
#         [-3.7992e+22,  2.4856e+24,  3.5988e+23,  7.0294e+22]])
